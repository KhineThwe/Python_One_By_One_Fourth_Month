# %% [markdown]
# ## Pandas

# %%
import pandas as pd


# df = pd.DataFrame()
# print(df)

lst = ['Java','For','Programmer']

# df = pd.DataFrame(lst)#row col format

myvar = pd.Series(lst,index=["x","y","z"])

print(myvar["y"])
# Out:
# For

# %% [markdown]
# ## Data Frame

# %%
data = {
    "calories":[420,380,390],
    "duration":[50,40,45]
}

myvar1 = pd.DataFrame(data,index=["day1","day2","day3"])
print(myvar1)
# print(myvar1["calories"])

print(myvar1.loc["day2"])#return row 

print(myvar1.loc[["day1","day2"]])#use a list of indexes
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# calories    380
# duration     40
# Name: day2, dtype: int64
#       calories  duration
# day1       420        50
# day2       380        40

# %% [markdown]
# ## Practice

# %%
df_begin = pd.DataFrame(
{
    "Name":[
        "Braund,Mr.Owen Harry",
        "Allice,Mr.William Henry",
        "David,Mr. Beckham",
    ],
    "Age":[22,33,44],
    "Sex":["male","female","male"],
})

print(df_begin)
print("Age Data",df_begin["Age"])
# Out:
#                       Name  Age     Sex
# 0     Braund,Mr.Owen Harry   22    male
# 1  Allice,Mr.William Henry   33  female
# 2        David,Mr. Beckham   44    male
# Age Data 0    22
# 1    33
# 2    44
# Name: Age, dtype: int64

# %% [markdown]
# ## Data Handling

# %%
#for csv
df = pd.read_csv('pokemon_data.csv')
# print(df)
print(df.head(3))


#for excel
df_xlsx = pd.read_excel('pokemon_data.xlsx')
print(df_xlsx.head(3))

#for txt file
df_txt = pd.read_csv('pokemon_data.txt',delimiter="\t")
print(df_txt.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# ...

# %% [markdown]
# ## Reading Data In Pandas

# %%
#Read Headers

# print(df.columns)

#Read Each col
# print(df[['Name','Type 1','HP']])

print(df.head(4))
# print(df.iloc[2])

# print(df.iloc[2,2])#second row first col


for index,row in df.iterrows():
    print(index,row["Name"])
    
#https://pandas.pydata.org/docs/getting_started/intro_tutorials/02_read_write.html#min-tut-02-read-write
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# ...

# %% [markdown]
# New heading

# %% [markdown]
# ## Sorting/Describing Data

# %%
# df.describe()

# df.sort_values("Name",ascending=False)#descending order

# df.sort_values(['Type 1','HP'],ascending=False)


df.sort_values(['Type 1','HP'],ascending=[1,0])#first one ascending ,second one descending order
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Making changes to the data

# %%
df.head(5)
#Adding new col
df['Total'] = df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']
print(df['Total'])
df.head(5)

#drop col
# df = df.drop(columns=['Total'])
# df.head(5)

# #Adding new col new way
# df['Total'] = df.iloc[:,4:10].sum(axis=1)#axis = 1 adding horizontally
# df.head(5)

#reorder column
#cols = list(df.columns.values)
# print(cols,type(cols))
# print(type(df.columns.values))

# df.head(5)

# df = df[cols[0:4]+[cols[-1]]+cols[4:11]]
# df.head(5)
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Name: Total, Length: 800, dtype: int64
#    #                   Name Type 1  Type 2  Sp. Def  Speed  Generation  \
# 0  1              Bulbasaur  Grass  Poison       65     45           1
# 1  2                Ivysaur  Grass  Poison       80     60           1
# 2  3               Venusaur  Grass  Poison      100     80           1
# 3  3  VenusaurMega Venusaur  Grass  Poison      120     80           1
# 4  4             Charmander   Fire     NaN       50     65           1
#
#    Legendary  Total  HP  Attack  Defense  Sp. Atk  count
# 0      False    318  45      49       49       65      1
# 1      False    405  60      62       63       80      1
# 2      False    525  80      82       83      100      1
# 3      False    625  80     100      123      122      1
# 4      False    309  39      52       43       60      1

# %% [markdown]
# ## Saving our Data(Exporting into Desired Format)

# %%
# df.to_csv('modified_ver1.csv',index=False)

# df.to_excel('modified_ver1.xlsx',index=False)

df.to_csv('modified_ver1.txt',index=False,sep='\t')#separater

# %% [markdown]
# ## Filtering Data

# %%
df.head(3)
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
# new_df 

new_df.reset_index(drop=True,inplace=True)
new_df

new_df.to_csv('filtered_ver1.csv')

# %%
# new_df1= df.loc[(df['Name'].str.contains('Mega'))]#only mega

new_df1= df.loc[(~df['Name'].str.contains('Mega'))]#except mega
new_df1

import re
# new_df2= df.loc[(df['Type 1'].str.contains('Fire|Grass',regex=True))]
new_df2= df.loc[(df['Type 1'].str.contains('fire|grass',flags=re.I,regex=True))]#flags=re.I means ignore case sensitive
new_df2.head(10)
# Out:
#      #                       Name Type 1  Type 2  Legendary  HP  Attack  \
# 0    1                  Bulbasaur  Grass  Poison      False  45      49
# 1    2                    Ivysaur  Grass  Poison      False  60      62
# 2    3                   Venusaur  Grass  Poison      False  80      82
# 3    3      VenusaurMega Venusaur  Grass  Poison      False  80     100
# 4    4                 Charmander   Fire     NaN      False  39      52
# 5    5                 Charmeleon   Fire     NaN      False  58      64
# 6    6                  Charizard   Fire  Flying      False  78      84
# 7    6  CharizardMega Charizard X   Fire  Dragon      False  78     130
# 8    6  CharizardMega Charizard Y   Fire  Flying      False  78     104
# 42  37                     Vulpix   Fire     NaN      False  38      41
#
#     Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0        49       65       65     45           1
# 1        63       80       80     60           1
# ...

# %% [markdown]
# ## Conditional Changes

# %%
df.head(5)
df.loc[df['Type 1']=='Fire','Generation'] = 'MZ'
df
# Out:
#        #                   Name   Type 1  Type 2 Legendary  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison     False  45     49      49
# 1      2                Ivysaur    Grass  Poison     False  60     62      63
# 2      3               Venusaur    Grass  Poison     False  80     82      83
# 3      3  VenusaurMega Venusaur    Grass  Poison     False  80    100     123
# 4     MZ                     MZ       MZ      MZ        MZ  MZ     MZ      MZ
# ..   ...                    ...      ...     ...       ...  ..    ...     ...
# 795  719                Diancie     Rock   Fairy      True  50    100     150
# 796  719    DiancieMega Diancie     Rock   Fairy      True  50    160     110
# 797  720    HoopaHoopa Confined  Psychic   Ghost      True  80    110      60
# 798  720     HoopaHoopa Unbound  Psychic    Dark      True  80    160      60
# 799   MZ                     MZ       MZ      MZ        MZ  MZ     MZ      MZ
#
# ...

# %% [markdown]
# ## Aggregate Statistics(Group by)

# %%
df= pd.read_csv('modified.csv')

#df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)#highest defense

# df.groupby(['Type 1']).mean().sort_values('Attack',ascending=False)

# df.groupby(['Type 1']).sum()

# df.groupby(['Type 1']).count()

df['count'] = 1
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# ## Working with large amounts of data

# %%
#new_df = pd.DataFrame(columns=df.columns)
for df in pd.read_csv('modified.csv',chunksize=5):#5 row df
     print(df)
#        results = df.groupby(['Type 1']).count()
#        new_df = pd.concat([new_df,results])
#        print(new_df)
# Out:
#    #                   Name Type 1  Type 2  Sp. Def  Speed  Generation  \
# 0  1              Bulbasaur  Grass  Poison       65     45           1
# 1  2                Ivysaur  Grass  Poison       80     60           1
# 2  3               Venusaur  Grass  Poison      100     80           1
# 3  3  VenusaurMega Venusaur  Grass  Poison      120     80           1
# 4  4             Charmander   Fire     NaN       50     65           1
#
#    Legendary  Total  HP  Attack  Defense  Sp. Atk
# 0      False    318  45      49       49       65
# 1      False    405  60      62       63       80
# 2      False    525  80      82       83      100
# 3      False    625  80     100      123      122
# 4      False    309  39      52       43       60
#    #                       Name Type 1  Type 2  Sp. Def  Speed  Generation  \
# 5  5                 Charmeleon   Fire     NaN       65     80           1
# 6  6                  Charizard   Fire  Flying       85    100           1
# ...
